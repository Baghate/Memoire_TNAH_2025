# %% [markdown]
# # Code pour scraper les datasets sur Thérèse Bonney et l'Exposition universelle de 1937 📷 🗃️
#
# **Enjeux techniques** 👨‍💻
# + Automatiser la distinction entre les sources.
# + Automatiser le nommage des fichiers et leur recensement dans la colonne "FICHIER" du csv.
# + Obtenir des images de bonne qualité.
# + Pouvoir suivre les étapes du scrapping pour identifier les problèmes.

# %% [markdown]
# ## /!\ Avertissement /!\ 🔺
#
# Ce code utilise la bibliothèque **Selenium** 🌕 pour scrapper le site des bibliothèques spécialisées de la ville de Paris. Cette bibliothèque a pour but d'émuler le comportement d'un utilisateur sur une page web dynamique (en javascript). De ce fait elle a besoin d'un **path vers le driver de votre navigateur**.
#
# Il vous faut impérativement avoir installé **Chrome** (ou **Chromium** pour Linux) comme navigateur. Puis, il faut que vous téléchargiez le driver depuis le lien 🔗 ci-dessous, pour que le script de scrapping puisse fonctionner.
#
# ***Chrome driver :***
#
# 🔗 https://googlechromelabs.github.io/chrome-for-testing/
#
# *Téléchargez le binary de "chromedriver" correspondant à votre OS, et exécutez l'installation.*
#
#
# 🖳 Sous linux téléchargez **Chromium** via le centre d'application ou en suivant ce lien :
#
# 🔗 https://code.launchpad.net/~chromium-team/chromium-browser/+git/snap-from-source

# %% [markdown]
# ## Environnement 🌐

# %% [markdown]
# ### Import des librairies 📖

# %%
import os
import re
import time
import shutil
import zipfile
import tempfile
import requests
import pandas as pd
from random import randint
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# ## Fonctions 🤖

# %% [markdown]
# ### Fonction principale de téléchargement d'images 💾

# %%
def download_image(input_csv, start_index=0): #On a besoin de start_index pour pouvoir remplacer cette valeur en cas d'interruption du scrapping
    """
    Cette fonction lit un fichier CSV contenant des URLs d'images et leurs notices associées,
    puis télécharge chaque image selon sa source (Gallica, Bibliothèques, etc.) en appelant
    la fonction de téléchargement appropriée.

    Args:
        input_csv (str): Chemin vers le fichier CSV contenant les URLs à traiter.
        start_index (int) : Index de départ utilisé pour lancer le téléchargement.
        

    Returns:
        bool: False uniquement en cas d'erreur lors de la lecture du fichier CSV.
              Sinon, la fonction ne retourne rien (None).
    """
    # Définition dynamique du chemin vers le folder d'output 

    output_folder = os.path.join(os.path.dirname(input_csv), 'sortie') # Le dossier de sortie se trouvera au même endroit que le csv qui contient les URLs.
    os.makedirs(output_folder, exist_ok=True) #S'il n'existe pas, il est créé.

    try:
        df = pd.read_csv(input_csv, sep=",", encoding="utf-8") # Ouverture du csv avec pandas comme DataFrame ⚠️ Utilisez le bon séparateur ⚠️
        print("Fichier CSV chargé avec succès.")
        if "FICHIER" not in df.columns: # Création de la colonne fichier qui viendra contenir les filepaths des images téléchargées.
            df["FICHIER"] = ""
        for index, row in df.iterrows(): # On lui dit d'itérer sur chaque ligne.
            if index < start_index: # L'index démarre par défaut à zéro, mais si la variable start_index est supérieure à 0 on ignore les lignes entre 0 et start_index.
                continue 
            try: # On vérifie quelle fonction on va appeler pour le téléchargement en fonction du site d'origine de l'image.
                url = row['URL']
                output_path = os.path.join(output_folder, f"image_{index:02d}.jpg") # On nomme les fichiers d'images en suivant l'index du csv.
                if url.startswith("https://gallica"): # On détecte l'URL de Gallica.
                    success = download_gallica(url, index, output_folder) # Et on appelle la fonction correspondante.
                    if success:
                        df.at[index, "FICHIER"] = output_path # Si le téléchargement réussi on ajoute à la ligne correspondante le filepath de l'image dans la colonne "FICHIER"
                        df.to_csv(input_csv, index=False, encoding="utf-8") # On sauvegarde les modifications.
                elif url.startswith('https://bibliotheques'): # Autrement on détecte que l'image provient du site des bibliothèques spécialisées de Paris. 
                    success = download_bib(url, index, output_folder, output_path) # On appelle la fonction idoine.
                    if success:
                        df.at[index, "FICHIER"] = output_path # Pareil on ajoute le filepath à la colonne "FICHIER"
                        df.to_csv(input_csv, index=False, encoding="utf-8") # On sauverharde les modifications.
                else:
                    print(f"Source non reconnue pour l'URL au n° d'index {index}") # Si une URL d'un autre site est présente dans notre CSV, ce message d'erreur nous permettra de savoir à quelle index du csv se trouve l'URL.
            except Exception as e:
                print(f"Erreur ligne {index}: {e}")
                continue
    except Exception as e:
        print(f"Erreur lors de la lecture du CSV : {e}") # Si le CSV ne s'est pas lu correctement, par exemple parce si le séparateur n'est pas le bon, ou l'encodage différent.   
        return False

# %% [markdown]
# ### Fonction spécifique pour Gallica 🐓

# %%
def download_gallica(url, index, output_folder):
    """
    Télécharge une image depuis Gallica
    
    Args:
        url (str): URL originale de Gallica
        index (int): Numéro de ligne dans le CSV
        output_folder (str): Dossier de destination
        
    Returns:
        bool: True si succès, False si échec
    """
    try:
        # 1. Transformer l'URL
        ark = url.split('ark:') # On isole dans la colonne URL la partie de l'url qui contient l'identifiant ark de l'image.
        if len(ark) <= 1: # On vérifie qu'on obtient pas une résultat vide.
            print(f"URL invalide à la ligne {index}") # Le cas échéant on imprime une erreur avec le numéro d'index pour voir d'où vient le problème.
            return False
        image_url = f"https://gallica.bnf.fr/iiif/ark:{ark[1]}/f1/full/max/0/default.jpg" # Sinon on forme l'URL IIIF de l'image pour l'ouvrir directement en plein écran et en bonne qualité pour le téléchargement.

        # 2. Télécharger
        timeout = randint(4,9) # Afin d'éviter un code 429 (Too many requests) de la part de Gallica on randomise le timeout entre les téléchargements.
        response = requests.get(image_url, stream=True, timeout=timeout) # On envoie la requête pour accéder à la ressource auprès du site.
        if response.status_code != 200: # On s'assure qu'on obtient bien un code 200, signifiant que tout est ok.
            print(f'Problème url {index}: status code {response.status_code}') # Sinon on print l'index de la ligne et le code d'erreur obtenu.
            return False

    
        # 3. Sauvegarder
        output_path = os.path.join(output_folder, f"image_{index:02d}.jpg") # On créer le nommage régulier des fichiers dans le chemin que nous avons défini dynamiquement dans la fonction générale.
        with open(output_path, 'wb') as file: # On ouvre en mode écriture binaire le fichier.
            for chunk in response.iter_content(1024): # On charge par chunks (morceaux) afin d'éviter de devoir charger en mémoire l'entièreté de l'image avant de la télécharger, ce qui peut être lourd et long avec des images de bonne qualité.
                file.write(chunk) # On télécharge.
        
        print(f"Image de Gallica téléchargée avec succès n° d'index {index} ") # Tout s'est bien passé, et on imprime le numéro d'index de la ligne pour suivre où nous en sommes.
        time.sleep(timeout) # On laisse un temps de pause entre deux téléchargements, toujours pour éviter un code 429.
        return True

    except Exception as e:
        print(f"Erreur pour l'URL Gallica n° d'index {index}: {e}") # Quelque chose ne s'est pas bien passé on print le numéro d'index et l'erreur rencontrée.
        return False

# %% [markdown]
# ### Fonctions spécifiques pour les bibliothèques spécialisées de Paris 🗼

# %% [markdown]
# #### Fonction pour gérer les cookies 🍪

# %%
def dismiss_cookies(driver):
    """
    Cette fonction tente de fermer ou d'ignorer une fenêtre de cookies en cliquant
    sur le corps de la page, ce qui peut suffire à la faire disparaître sur certains sites.

    Args:
        driver (selenium.webdriver): Instance active du navigateur pilotée par Selenium.

    Returns:
        None
    """
    wait = WebDriverWait(driver, 5) # On attends 5 secondes que la page se charge.
    body = wait.until(EC.presence_of_element_located((By.TAG_NAME, "body"))) # Dès que l'élément "body" de la page HTML apparaît on arrête d'attendre.
    ActionChains(driver).move_to_element(body).click().perform() # On clique dès lors n'importe où sur le corps de la page pour faire disparaître les cookies.

# %% [markdown]
# #### Fonction pour dézipper, déplacer et renommer les fichiers 🤐

# %%
def process_zip_file(zip_path, index, output_folder, timeout=30):
    """
    Traite le fichier ZIP téléchargé
    
    Args:
        zip_path (str): Chemin du fichier ZIP téléchargé
        index (int): Index pour le nommage
        output_folder (str): Dossier de destination final
        timeout (int): Temps maximum d'attente en secondes
    
    Returns:
        bool: True si succès, False si échec
    """
    try:
        start_time = time.time() # Sert à commencer à décompter le temps, on utilise un "timeout" plus loin, la fonction a donc besoin de savoir combien de temps s'est écoulé depuis qu'elle a démarrée.
        

        if not os.path.exists(zip_path): # Vérification que le ZIP existe.
            print(f"ZIP non trouvé: {zip_path}") # Sinon on dit où est-ce qu'on a pas trouvé le ZIP.
            return False
            
        with tempfile.TemporaryDirectory() as temp_dir: # On crée un dossier temporaire pour dézipper le dossier.
            with zipfile.ZipFile(zip_path, 'r') as zip_ref: # On accède en lecture au dossier zip.
                zip_ref.extractall(temp_dir) # On extrait le dossier. 
            
            image_found = False
            for root, _, files in os.walk(temp_dir): # On parcours le dossier extrait pour y trouver l'image
                if time.time() - start_time > timeout: # On met une limite de temps à ce traitement.
                    print(f"Timeout lors du traitement du ZIP n° d'index {index}") # Si aucun fichier n'est trouvé après le temps imparti on imprime un message d'erreur avec l'index.
                    return False                    
                for file in files:
                    if file.lower().endswith(('.jpg', '.jpeg', '.png')): # On cherche les fichiers qui finissent par ...
                        # 4. Déplacer et renommer l'image
                        src = os.path.join(root, file) # On prend le fichier à déplacer dans le dossier temporaire, la variable src étant le chemin complet de ce dossier temporaire.
                        dst = os.path.join(output_folder, f"image_{index:02d}{os.path.splitext(file)[1]}") # Ici c'est le chemin de destination de l'image et la norme de nommage de l'image au moment du déplacement.
                        shutil.move(src, dst) # On bouge et renomme le fichier depuis le dossier temporaire jusqu'au dossier de sortie final.

# 💬 Ici on ne supprime pas directement le dossier zip des Téléchargements, on le fait plus tard, dans la fonction downloab_bib.
                  
                        
                        if os.path.exists(dst): # On vérifie que l'image a bien été déplacée et existe
                            image_found = True
                            print(f"Image {index} extraite et déplacée avec succès ✅") # Si c'est le cas on imprime un message de réussite.
                            break # On casse la boucle "for file in files:" quand une image a été trouvée, déplacée et renommée.
                        
                        # Le code reprend ici à la boucle supérieure "for root, _, files in os.walk(temp_dir):"
                
            if not image_found:
                print(f"Aucune image trouvée dans le ZIP n° d'index {index}")
                return False # Ici on met fin à la boucle citée précédemment, soit parce que ça a échoué.
                
            return True # Soit parce que ça a réussi.
        
    except Exception as e:
        print(f"Erreur traitement ZIP n° d'index {index}: {e}") # Gestion d'erreur, en cas de problème à un quelconque moment de la fonction, déclenche ce message d'erreur avec l'index et le message produit.
        return False

# %% [markdown]
# #### Fonction pour détecter le webdriver installé sur la machine 🚀

# %%
def find_webdriver(): # Afin d'assurer la portabilité du code nous devons prendre en compte les différentes types d'OS.

# On met en clair dans le code les chemins classiques, attendus, que la fonction download_bib pourra interroger afin de lancer Chromedriver.

# 👁️‍🗨️⚠️ Si vous installez Chromedriver à un endroit personnalisé, vous devrez mentionner son path ici pour que le scrapping puisse fonctionner.
    chrome_paths = [
        "/usr/local/bin/chromedriver",  # Linux/Mac
        "/usr/bin/chromedriver",        # Linux
        "C:\\Program Files\\Google\\Chrome\\Application\\chromedriver.exe",  # Windows
        "C:\\chromedriver.exe"          # Windows
    ]
    for path in chrome_paths:
        if os.path.exists(path): # On vérifie que Chromedriver existe bel et bien à l'un de ces chemins.
            return path
    raise FileNotFoundError("Aucun chromedriver trouvé. Installez chromedriver. Vérifiez qu'il se situe bien aux endroits attendus dans la variable 'chrome_paths'") # Le cas échéant nous invitons l'utilisateur à réinstaller Chromedriver, en précisant cette fois son path ci-dessus.

# %% [markdown]
# #### Fonction pour gérer les pages contenant plusieurs images 🖼️

# %%
def handle_multi_img_case(driver, index):
    """
    Si plusieurs images sont présentes sur la page, clique sur la première,
    gère le basculement d'onglet, ferme l'onglet original, puis retourne True si succès, False sinon.
    
    Args:
        driver (selenium.webdriver): Instance active du navigateur Selenium.
        index (int): Index de la ligne en cours (pour le suivi/log).

    Returns:
        bool: True si le switch et la fermeture de l'onglet original ont réussi, False sinon.
    """
    try:
        container_xpath = "/html/body/div[1]/div/div[1]/div/div[1]/div/div/div[2]/div/div[1]/div/div/div/main/div/div/div/div/div/div[2]/div/div/div[1]/div/div/div[1]/div/div[2]"
        container = driver.find_element(By.XPATH, container_xpath) # Si la page a plusieurs images c'est toujours dans cette div
        img_elements = container.find_elements(By.TAG_NAME, "img") # Il y aura la présence de plusieurs img=class dans ce cas
        if len(img_elements) > 1: # Donc si img_elements est supérieur à 1
            img_elements[0].click() # On clique sur le premier
            print(f"Plusieurs images détectées, première image cliquée au n° d'index {index}")
            original_window = driver.current_window_handle # On définit une variable original_window pour gérer la fermeture des fenêtres plus tard, on lui dit que c'est celle qu'on manipule maintenant
            time.sleep(1) # On attend.
            WebDriverWait(driver, 10).until(lambda d: len(d.window_handles) > 1) # Ici on attends jusqu'a ce qu'il y ait plus d'un onglet.
            time.sleep(1)
            # Trouver la nouvelle fenêtre
            new_window = None # Pour l'instant on définit que new_window est vide pour le peupler après.
            for window_handle in driver.window_handles:
                if window_handle != original_window: # Ici on définit que si la page sur laquelle on est est différente de celle de case alors c'ets la nouvelle page
                    new_window = window_handle
                    break
            if new_window is None: # Ici c'est si ça n'a pas marché on lui retourne un message d'erreur.
                print(f"Impossible de trouver la nouvelle fenêtre au n° d'index {index}")
                return False
            driver.switch_to.window(new_window) #Ici on switch sur ce qu'on a définit comme étant le nouvel onglet.
            time.sleep(1)
            WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.TAG_NAME, "body")) # Ici on attends jusqu'à ce qu'on ait le body.
            )
            time.sleep(1)
            # Fermer l'onglet original
            driver.switch_to.window(original_window) # On bascule sur l'onglet de base.
            time.sleep(1)
            driver.close() # On le ferme.
            time.sleep(1)
            # Revenir sur le nouvel onglet
            driver.switch_to.window(new_window) # Enfin on reviens sur le nouvel onglet.
            time.sleep(1)
            print(f"Basculé sur la nouvelle fenêtre et fermé l'onglet original pour l'image au n° d'index {index}")
            return True
        else:
            return False
    except Exception as e:
        print("Pas de gestion multi-image pour cette URL")
        return False

# %% [markdown]
# #### Fonction de crawling et de téléchargement 🦀

# %%
def download_bib(url, index, output_folder, output_path): # Fonction qui automatise la navigation sur les pages web du site des bibliothèque de Paris.
    """
    Fonction pour interagir avec les pages des bibliothèques spécialisées de Paris

        Args:
        url (str): URL originale de Gallica
        index (int): Numéro de ligne dans le CSV
        output_folder (str): Dossier de destination
        output_path (str): nom du filepath des images téléchargées
    Returns:
        bool: True si succès, False si échec
    """
    try:
        driver_path = find_webdriver() # On cherche l'instance chromedriver en fonction du path qui a été trouvé dans la fonction précédente.
        user_data_dir = tempfile.mkdtemp() # On créer un instance temporaire avec des informations de profil temporaires.

        options = webdriver.ChromeOptions() # On liste les options de lancement de Chrome via Selenium.
        options.add_argument("--no-sandbox") #Désactive le mode "sandbox" de Chrome, qui "conteneurise" les onglets et les pages pour éviter les conflits de lancement notamment en serveur docker ou sur Linux.
        options.add_argument(f"--user-data-dir={user_data_dir}") # Spécifie un dossier temporaire pour le profil utilisateur Chrome. Cela permet d’isoler la session de navigation de Selenium du profil Chrome habituel.
        options.add_argument("--headless=new") # N'affiche pas l'interface graphique, possibilité de commenter la ligne pour voir le scrapping se faire.
        options.add_argument("--disable-dev-shm-usage") # Empêche Chrome d’utiliser /dev/shm (mémoire partagée). Sur certains systèmes (ex : Docker), la mémoire partagée est limitée et cela évite des plantages.
        options.add_argument("--disable-gpu") #Désactive l’accélération matérielle GPU. Recommandé en mode headless ou sur des serveurs sans GPU.
        options.add_argument("--remote-debugging-port=9222") # Ouvre le port 9222 pour le débogage à distance de Chrome. Nécessaire pour certaines fonctionnalités avancées ou pour le support du mode headless.
        
# ⚠️ Par défaut on indique le chemin vers le dossier des Téléchargements pour que Chrome sache où mettre les dossiers qu'on lui demande de télécharger.
# ⚠️ Possibilité de changer le chemin pour éviter les conflits si d'autres dossiers .zip se trouvent dans vos Téléchargements. Sinon ce n'est qu'un dossier intérmédiaire, pas besoin d'un dossier dédié, les .zip sont supprimés après chaque téléchargement.      
        
        # Préférences pour le téléchargement automatique des ZIP
        prefs = {
            "download.default_directory": os.path.expanduser("~/Téléchargements"), # On indique au navigateur la destination que doivent prendre les fichiers téléchargés.
            "download.prompt_for_download": False, # Ne demande pas à l'utilisateur, via un pop-up, où télécharger un fichier.
            "download.directory_upgrade": True, # Permet d'utiliser le nouveau dossier de téléchargement même si un téléchargement est déjà en cours.
            "safebrowsing.enabled": True # Active la protection contre les fichiers malveillants
        }
        options.add_experimental_option("prefs", prefs) # On applique le contenu de notre variable prefs à la méthode qui régit les options de lancement Chrome.

        service = Service(driver_path) # On dit que 'service' est de la classe Service, qui lance ou coupe le navigateur et on lui donne comme argument le chemin vers le driver pour qu'il puisse s'exécuter.
        driver = webdriver.Chrome(service=service, options=options) # On lance le driver via Selenium avec nos options précédemment définies.

        try:
            # 1. Charger la page
            print(f"Chargement de la page {index}...")
            driver.get(url) # On se connecte à l'URL.
            time.sleep(5) # On attends 5 secondes.
            # Vérifier que la page est bien chargée
            if "Erreur" in driver.title or "404" in driver.title:
                print(f"Problème de chargement de la page au n° d'index {index} (titre: {driver.title})")# On fait de la gestion d'erreur où on affiche le titre de la page et l'index.
            else:
                print(f"Page chargée avec succès au n° d'index {index} (titre: {driver.title})") # On manifeste la réussite du chargement avec l'index et le titre correspondant.

            # 2. Gérer les cookies
            try:
                dismiss_cookies(driver) # On fait appel à notre fonction pour dissiper la fenêtre des cookies qui apparaît.
            except Exception as e:
                print(f"Erreur cookies: {e}, on continue...")
                    
            # 3. Afficher l'image en grand dans une autre fenêtre
            if handle_multi_img_case(driver, index):
            # Si la fonction a géré le cas multi-img, passer directement à l'étape 5 (bouton téléchargement)
                pass  # Le code continue à l'étape 5
            try:
                image = WebDriverWait(driver, 5).until(
                    EC.element_to_be_clickable((By.XPATH, "//*[@id='fullscreen']"))
                )
                image.click()
                print(f"Bouton fullscreen cliqué n° d'index {index}")
            except Exception:
                try:
                    image = WebDriverWait(driver, 5).until(
                        EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div/div[1]/div/div[1]/div/div/div[2]/div/div[1]/div/div/div/main/div/div/div/div/div/div[1]/div[2]/div/div[1]/img"))
                    )
                    print(f"Image trouvée par XPATH principal (classique) n° d'index {index}")
                except Exception:
                    try:
                        image = WebDriverWait(driver, 5).until(
                            EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div/div[1]/div/div[1]/div/div/div[2]/div/div[1]/div/div/div/main/div/div/div/div/div/div[1]/div[1]/div/div[1]/img"))
                        )
                        print(f"Image trouvée par XPATH alternatif (classique) n° d'index {index}")
                    except Exception:
                        try:
                            image = WebDriverWait(driver, 5).until(
                                EC.element_to_be_clickable((By.XPATH, "//img[@role='presentation']"))
                            )
                            print(f"Image trouvée par rôle 'presentation' (classique) au n° d'index {index}")
                        except Exception:
                            print(f"Impossible de trouver l'image au n° d'index {index} avec toutes les méthodes")
                            raise Exception("Image non trouvée")
                if image.tag_name == "img":
                    driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", image)
                    time.sleep(0.5)  # Facultatif mais souvent utile
                    try:
                        image.click()
                    except Exception as e:
                        print(f"Click classique échoué, tentative JS click... {e}")
                        driver.execute_script("arguments[0].click();", image)
                    print(f"Image cliquée au n° d'index {index}")
                else:
                    print(f"Élément trouvé mais ce n'est pas une image ligne {index}")
                    raise Exception("Pas un élément image")
            except Exception as e:
                print(f"Impossible de trouver l'image au n° d'index {index}: {e}")
                raise

            # 4. Basculer sur la nouvelle fenêtre
            try:
                WebDriverWait(driver, 10).until(lambda d: len(d.window_handles) > 1) # Ici il faut qu'on bascule sur une fenêtre pop-up pour la suite du scrapping.
                # On attends donc 10 secondes le chargement puis on passe par une fonction lambda qui simplement nous permet de basculer à l'autre fenêtre s'il y a plus d'une fenêtre en même temps (donc si la deuxième est apparue)
                # La session Chrome est stoppée après chaque téléchargement donc il n'y aura jamais plus de deux onglets sur la même fenêtre c'est pour cela qu'on peut passer par cette fonction lambda.
                original_window = driver.current_window_handle # On définit cette variable pour dire que la page sur laquelle on était, était la page originale, celle qu'on va donc quitter.
                for window_handle in driver.window_handles:
                    if window_handle != original_window: # Si donc il y a une seconde fenêtre différente de celle originale.
                        driver.switch_to.window(window_handle) # On utilise la méthode qui permet de passer d'une fenêtre à l'autre.
                        break
                print(f"Basculé sur la nouvelle fenêtre pour l'image au n° d'index {index}")
                    
            except Exception as e:
                print(f"Impossible de basculer sur la nouvelle fenêtre au n° d'index {index}: {e}")
                raise

            # 5. Appuyer sur le bouton "Téléchargement"
            try:
                dl = WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, "//*[@id='hires']"))
                ) # Même logique que pour afficher l'image en grand, on attend que l'élément du bouton de téléchargement soit chargé.
                if dl.tag_name == "div": # On s'assure qu'il est de la bonne nature. 
                    dl.click() # On clique dessus.       
                    print(f"Bouton téléchargement trouvé et cliqué au n° d'index {index}")
                else:
                    print(f"Élément trouvé mais ce n'est pas un bouton de téléchargement {index}")
                    raise Exception("Pas un bouton de téléchargement") # Ce qu'on a trouvé n'était pas de la bonne nature.
                
            except Exception as e:
                print(f"Impossible de trouver le bouton de téléchargement au n° d'index {index}: {e}")
                raise

            # 6. Cocher la checkbox
            try:
                checkbox = WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, "//*[@id='checkConditions']"))
                ) # Même logique qu'avant, on doit attendre qu'un nouvel élément dynamique apparaisse, cette fois-ci c'est une case à cocher.
                if checkbox.get_attribute('type') == "checkbox": # On vérifie sa nature.
                    checkbox.click() # Si la nature est la bonne, on clique.       
                    print(f"Checkbox des conditions trouvée et cochée au n° d'index {index}")
                else:
                    print(f"Élément trouvé mais ce n'est pas une checkbox {index}")
                    raise Exception("Pas une checkbox")
                
            except Exception as e:
                print(f"Impossible de trouver la checkbox au n° d'index {index}: {e}")
                raise
            
            # 7. Appuyer sur le bouton download
            try:
                dl_button = WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, "/html/body/div[4]/div[3]/div/button"))
                ) # Même logique, on attends que le bouton de download final apparaisse et on clique dessus.
                if dl_button.tag_name == "button": # On vérifie sa nature.
                    dl_button.click() # On clique.       
                    print(f"Bouton de téléchargement final trouvé et cliqué au n° d'index {index}")
                else:
                    print(f"Élément trouvé mais ce n'est pas le bouton pour télécharger {index}")
                    raise Exception("Pas un bouton de téléchargement")
                
            except Exception as e:
                print(f"Impossible de trouver le button pour télécharger l'image au n° d'index {index}: {e}")
                raise

            # 8. Attendre le téléchargement et traiter le ZIP
            try:
                # Attendre pour le téléchargement
                time.sleep(15)  
                
                # Vérifier que le dossier Téléchargements existe
                downloads_dir = os.path.expanduser("~/Téléchargements")
                if not os.path.exists(downloads_dir):
                    raise Exception(f"Dossier Téléchargements non trouvé: {downloads_dir}")
                    
                # Vérifier qu'il y a des fichiers dans le dossier
                files = os.listdir(downloads_dir)
                if not files:
                    raise Exception("Dossier Téléchargements vide")
                    
                # Trouver le dernier fichier ZIP
                zip_files = [f for f in files if f.endswith('.zip')]
                if not zip_files:
                    raise Exception("Aucun fichier ZIP trouvé dans Téléchargements")
                    
                latest_zip = max([os.path.join(downloads_dir, f) for f in zip_files], 
                                key=os.path.getctime) # Cette ligne crée une liste des chemins complets de tous les fichiers ZIP présents dans le dossier de téléchargement,
# puis sélectionne celui qui a la date de création la plus récente (le dernier ZIP téléchargé).
# Cela permet de cibler automatiquement le fichier ZIP qui vient d'être téléchargé pour le traiter ensuite.
                
                print(f"Fichier ZIP trouvé: {latest_zip}")
                
                # Traiter le ZIP
                if not process_zip_file(latest_zip, index, output_folder):
                    raise Exception("Échec du traitement du ZIP")
                    
                # Suppression du ZIP traité
                os.remove(latest_zip)
                print(f"ZIP supprimé avec succès")
                            
            except Exception as e:
                print(f"Erreur traitement fichier téléchargé au n° d'index {index}: {e}")
                raise

            return True # On retourne que tout s'est bien passé.
            
        finally:
            driver.quit() # On ferme le chromedriver.
            
    except Exception as e:
        print(f"Erreur configuration Selenium au n° d'index {index}: {e} ❌")
        return False

# %% [markdown]
# ### Fonction pour reprendre une session de scrapping interrompue 🤕

# %%
def resume_scrapping(output_folder):
    """
    Cette fonction sert à reprendre un téléchargement en cours de route s'il s'est arrêté subitement.
    Elle retourne l'index de la dernière image téléchargée dans le dossier de sortie.
    Args:
        output_folder (str): Dossier de destination des images téléchargées.
    Returns:
        int: L'index le plus élevé trouvé dans les noms de fichiers, ou -1 si aucun fichier n'est trouvé.
    """
    
    files = os.listdir(output_folder) # On liste tous les fichiers présents dans le dossier de sortie.
   
    max_index = -1  # Initialise la variable max_index à -1, afin de s'assurer qu'on a pas encore d'image dans le dossier.

    for name in files:     # Parcourt chaque nom de fichier dans le dossier.
       
        match = re.match(r'image_(\d+)\.\w+', name)  # Cherche un nom de fichier qui correspond au format "image_<nombre>.<extension>".
        if match: # Si le nom correspond, extrait l'index numérique du nom de fichier.
            idx = int(match.group(1))   # Met à jour max_index si l'index trouvé est supérieur à l'actuel.
            if idx > max_index:
                max_index = idx
   
    return max_index  # Retourne l'index le plus élevé trouvé (ou -1 si aucun fichier ne correspond).

# %% [markdown]
# ## Processing ⚙️

# %%
input_csv = "/home/mathieu/Documents/Stage/datasets/dataset_ExpoUniv1937/Expo_1937_photos.csv"

# %% [markdown]
# ### Lancement du scrapping pour la première fois 🎂
#
# **S'il a déjà été lancé, qu'il s'est stoppé subitement ou que nous l'avons arrêté sciemment, pour le reprendre là où il s'est arrêté, décommentez la cellule suivante 🩹 et reprenez le téléchargement en l'exécutant.**
#
# ⚠️🌪️ Ici si vous relancez un scrapping déjà entamé avec la cellule ci-dessous, il recommencera du début et écrasera les photos déjà présentes. 🌪️⚠️

# %%
# Lancer le scrapping pour la première fois
download_image(input_csv)
# Out:
# Fichier CSV chargé avec succès.
# Chargement de la page 0...
# Page chargée avec succès au n° d'index 0 (titre: [Etude publicitaire pour le] cognac Bisquit. [Enseigne publicitaire monumentale pour] l'Exposition internationale des Arts et Techniques dans la vie moderne : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Plusieurs images détectées, première image cliquée au n° d'index 0
# Basculé sur la nouvelle fenêtre et fermé l'onglet original pour l'image au n° d'index 0
# Image trouvée par XPATH alternatif (classique) n° d'index 0
# Image cliquée au n° d'index 0
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 0
# Bouton téléchargement trouvé et cliqué au n° d'index 0
# Checkbox des conditions trouvée et cochée au n° d'index 0
# Bouton de téléchargement final trouvé et cliqué au n° d'index 0
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/h__ark__73873_pf0001836977_2035_C9C92FD47F07299811822D830C1D64A6.zip
# Image 0 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 1...
# Page chargée avec succès au n° d'index 1 (titre: [Etude publicitaire pour Robert Lang. Exposition internationale des Arts et techniques de 1937. Hall du pavillon de la Suède et vue d'ensemble du Trocadéro] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Plusieurs images détectées, première image cliquée au n° d'index 1
# Basculé sur la nouvelle fenêtre et fermé l'onglet original pour l'image au n° d'index 1
# Image trouvée par XPATH alternatif (classique) n° d'index 1
# Image cliquée au n° d'index 1
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 1
# Bouton téléchargement trouvé et cliqué au n° d'index 1
# Checkbox des conditions trouvée et cochée au n° d'index 1
# Bouton de téléchargement final trouvé et cliqué au n° d'index 1
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/h__ark__73873_pf0001789722_0176_B566ED4BDE49982A0FB0C66314A20B4D.zip
# Image 1 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Image de Gallica téléchargée avec succès n° d'index 2
# Image de Gallica téléchargée avec succès n° d'index 3
# Image de Gallica téléchargée avec succès n° d'index 4
# Image de Gallica téléchargée avec succès n° d'index 5
# Image de Gallica téléchargée avec succès n° d'index 6
# Image de Gallica téléchargée avec succès n° d'index 7
# Image de Gallica téléchargée avec succès n° d'index 8
# Image de Gallica téléchargée avec succès n° d'index 9
# Image de Gallica téléchargée avec succès n° d'index 10
# Image de Gallica téléchargée avec succès n° d'index 11
# Chargement de la page 12...
# Page chargée avec succès au n° d'index 12 (titre: [Exposition internationale des Arts et Techniques dans la Vie Moderne. 1937. Chandeliers en cristal dessinés par Jean Luce. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 12
# Image cliquée au n° d'index 12
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 12
# Bouton téléchargement trouvé et cliqué au n° d'index 12
# Checkbox des conditions trouvée et cochée au n° d'index 12
# Bouton de téléchargement final trouvé et cliqué au n° d'index 12
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001614838_8EE1B97F89A0A5C7AB119AAAFBFE248D.zip
# Image 12 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 13...
# Page chargée avec succès au n° d'index 13 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Dîner des responsables au restaurant La Tour d'Argent.] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 13
# Image cliquée au n° d'index 13
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 13
# Bouton téléchargement trouvé et cliqué au n° d'index 13
# Checkbox des conditions trouvée et cochée au n° d'index 13
# Bouton de téléchargement final trouvé et cliqué au n° d'index 13
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001678746_7514AECDE7D55D5AF45FA85E6D016961.zip
# Image 13 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 14...
# Page chargée avec succès au n° d'index 14 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Dîner des responsables au restaurant La Tour d'Argent.] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 14
# Image cliquée au n° d'index 14
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 14
# Bouton téléchargement trouvé et cliqué au n° d'index 14
# Checkbox des conditions trouvée et cochée au n° d'index 14
# Bouton de téléchargement final trouvé et cliqué au n° d'index 14
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001678726_F19D8D639988F46C430B4E06704B1327.zip
# Image 14 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 15...
# Page chargée avec succès au n° d'index 15 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Dîner des responsables de l'exposition à La Tour d'Argent. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Plusieurs images détectées, première image cliquée au n° d'index 15
# Basculé sur la nouvelle fenêtre et fermé l'onglet original pour l'image au n° d'index 15
# Image trouvée par XPATH alternatif (classique) n° d'index 15
# Image cliquée au n° d'index 15
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 15
# Bouton téléchargement trouvé et cliqué au n° d'index 15
# Checkbox des conditions trouvée et cochée au n° d'index 15
# Bouton de téléchargement final trouvé et cliqué au n° d'index 15
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/h__ark__73873_pf0001615027_0001_B6FCEF6EB14F033C6CC5AC0B1CDAE339.zip
# Image 15 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 16...
# Page chargée avec succès au n° d'index 16 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Musée d'Art Moderne. "Allégorie à la gloire des arts" ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 16
# Image cliquée au n° d'index 16
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 16
# Bouton téléchargement trouvé et cliqué au n° d'index 16
# Checkbox des conditions trouvée et cochée au n° d'index 16
# Bouton de téléchargement final trouvé et cliqué au n° d'index 16
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615202_631AB5B08AD831737269FE5370917123.zip
# Image 16 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 17...
# Page chargée avec succès au n° d'index 17 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Musée d'Art Moderne. "Allégorie à la gloire des arts". ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 17
# Image cliquée au n° d'index 17
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 17
# Bouton téléchargement trouvé et cliqué au n° d'index 17
# Checkbox des conditions trouvée et cochée au n° d'index 17
# Bouton de téléchargement final trouvé et cliqué au n° d'index 17
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615195_A3AD8E5D8085DB0BB44378633F632797.zip
# Image 17 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 18...
# Page chargée avec succès au n° d'index 18 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Musée d'Art Moderne. "Allégorie à la gloire des arts"] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 18
# Image cliquée au n° d'index 18
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 18
# Bouton téléchargement trouvé et cliqué au n° d'index 18
# Checkbox des conditions trouvée et cochée au n° d'index 18
# Bouton de téléchargement final trouvé et cliqué au n° d'index 18
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615207_893D7FE5C4135EB01E9AF2CDB63DC689.zip
# Image 18 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 19...
# Page chargée avec succès au n° d'index 19 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Musée d'Art Moderne. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 19
# Image cliquée au n° d'index 19
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 19
# Bouton téléchargement trouvé et cliqué au n° d'index 19
# Checkbox des conditions trouvée et cochée au n° d'index 19
# Bouton de téléchargement final trouvé et cliqué au n° d'index 19
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615209_4E2625B22C4BDDB609C23934663E5E21.zip
# Image 19 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 20...
# Page chargée avec succès au n° d'index 20 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Musée d'Art Moderne. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 20
# Image cliquée au n° d'index 20
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 20
# Bouton téléchargement trouvé et cliqué au n° d'index 20
# Checkbox des conditions trouvée et cochée au n° d'index 20
# Bouton de téléchargement final trouvé et cliqué au n° d'index 20
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615192_0556B15A6E15DACE24E75D4F851AD450.zip
# Image 20 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 21...
# Page chargée avec succès au n° d'index 21 (titre: [Exposition internationale des Arts et techniques dans la Vie moderne. 1937. Palais des tissus, des Gobelins et de l'UCAF. Taffetas. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 21
# Image cliquée au n° d'index 21
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 21
# Bouton téléchargement trouvé et cliqué au n° d'index 21
# Checkbox des conditions trouvée et cochée au n° d'index 21
# Bouton de téléchargement final trouvé et cliqué au n° d'index 21
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615302_947A8A60C22ABB5BB824886E30B28156.zip
# Image 21 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 22...
# Page chargée avec succès au n° d'index 22 (titre: [Exposition internationale des Arts et techniques dans la Vie moderne. 1937. Palais des tissus, des Gobelins et de l'UCAF. Taffetas. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 22
# Image cliquée au n° d'index 22
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 22
# Bouton téléchargement trouvé et cliqué au n° d'index 22
# Checkbox des conditions trouvée et cochée au n° d'index 22
# Bouton de téléchargement final trouvé et cliqué au n° d'index 22
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615301_4D49A36C449154D41E9E33B412E5DCD7.zip
# Image 22 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 23...
# Page chargée avec succès au n° d'index 23 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Pavillon de l'Electricité. Laboratoire expérimental. Ingénieur en train de tester les solénoïdes. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 23
# Image cliquée au n° d'index 23
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 23
# Bouton téléchargement trouvé et cliqué au n° d'index 23
# Checkbox des conditions trouvée et cochée au n° d'index 23
# Bouton de téléchargement final trouvé et cliqué au n° d'index 23
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001769729_EA50EC82E2EF8353294395C2E169BE3B.zip
# Image 23 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 24...
# Page chargée avec succès au n° d'index 24 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Jean Perrin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 24
# Image cliquée au n° d'index 24
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 24
# Bouton téléchargement trouvé et cliqué au n° d'index 24
# Checkbox des conditions trouvée et cochée au n° d'index 24
# Bouton de téléchargement final trouvé et cliqué au n° d'index 24
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001678947_8B8B611202B3F7BD6A83E15730D4122C.zip
# Image 24 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 25...
# Page chargée avec succès au n° d'index 25 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Jean Perrin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 25
# Image cliquée au n° d'index 25
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 25
# Bouton téléchargement trouvé et cliqué au n° d'index 25
# Checkbox des conditions trouvée et cochée au n° d'index 25
# Bouton de téléchargement final trouvé et cliqué au n° d'index 25
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001678949_9746DDB197F9E36C5DF55BDB617A7BA4.zip
# Image 25 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 26...
# Page chargée avec succès au n° d'index 26 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Jean Perrin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 26
# Image cliquée au n° d'index 26
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 26
# Bouton téléchargement trouvé et cliqué au n° d'index 26
# Checkbox des conditions trouvée et cochée au n° d'index 26
# Bouton de téléchargement final trouvé et cliqué au n° d'index 26
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674395_861B9B35EB9376634A8E0A4355912216.zip
# Image 26 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 27...
# Page chargée avec succès au n° d'index 27 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Marcel Lods et Eugène Beaudouin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 27
# Image cliquée au n° d'index 27
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 27
# Bouton téléchargement trouvé et cliqué au n° d'index 27
# Checkbox des conditions trouvée et cochée au n° d'index 27
# Bouton de téléchargement final trouvé et cliqué au n° d'index 27
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674080_6FFCC014AF3189DFDE1ECB42A8E7DD2A.zip
# Image 27 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 28...
# Page chargée avec succès au n° d'index 28 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Marcel Lods et Eugène Beaudouin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 28
# Image cliquée au n° d'index 28
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 28
# Bouton téléchargement trouvé et cliqué au n° d'index 28
# Checkbox des conditions trouvée et cochée au n° d'index 28
# Bouton de téléchargement final trouvé et cliqué au n° d'index 28
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674082_DC08A2448F7789EAA1A973BCD99EDAFF.zip
# Image 28 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 29...
# Page chargée avec succès au n° d'index 29 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Marcel Lods et Eugène Beaudouin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 29
# Image cliquée au n° d'index 29
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 29
# Bouton téléchargement trouvé et cliqué au n° d'index 29
# Checkbox des conditions trouvée et cochée au n° d'index 29
# Bouton de téléchargement final trouvé et cliqué au n° d'index 29
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001679505_1FDA4241111D7BB63D5E11642C02E855.zip
# Image 29 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 30...
# Page chargée avec succès au n° d'index 30 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Marcel Lods et Eugène Beaudouin. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 30
# Image cliquée au n° d'index 30
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 30
# Bouton téléchargement trouvé et cliqué au n° d'index 30
# Checkbox des conditions trouvée et cochée au n° d'index 30
# Bouton de téléchargement final trouvé et cliqué au n° d'index 30
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001679507_DFD2BD9E23FCE54EABFA181CC20192D5.zip
# Image 30 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 31...
# Page chargée avec succès au n° d'index 31 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Maurice Martenot et sa femme Ginette Martenot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 31
# Image cliquée au n° d'index 31
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 31
# Bouton téléchargement trouvé et cliqué au n° d'index 31
# Checkbox des conditions trouvée et cochée au n° d'index 31
# Bouton de téléchargement final trouvé et cliqué au n° d'index 31
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674072_42826DF0F9061E151EF98CB7F441048E.zip
# Image 31 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 32...
# Page chargée avec succès au n° d'index 32 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Maurice Martenot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 32
# Image cliquée au n° d'index 32
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 32
# Bouton téléchargement trouvé et cliqué au n° d'index 32
# Checkbox des conditions trouvée et cochée au n° d'index 32
# Bouton de téléchargement final trouvé et cliqué au n° d'index 32
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673800_D103CB84161B0997F876FE2699EE802D.zip
# Image 32 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 33...
# Page chargée avec succès au n° d'index 33 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Maurice Martenot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 33
# Image cliquée au n° d'index 33
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 33
# Bouton téléchargement trouvé et cliqué au n° d'index 33
# Checkbox des conditions trouvée et cochée au n° d'index 33
# Bouton de téléchargement final trouvé et cliqué au n° d'index 33
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674074_A9CBD3DBEE0AE8DD40CC7F6E527C6182.zip
# Image 33 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 34...
# Page chargée avec succès au n° d'index 34 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Maurice Martenot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 34
# Image cliquée au n° d'index 34
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 34
# Bouton téléchargement trouvé et cliqué au n° d'index 34
# Checkbox des conditions trouvée et cochée au n° d'index 34
# Bouton de téléchargement final trouvé et cliqué au n° d'index 34
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674069_9C778B3DE4C1F5E4B283DB3F4B204E0F.zip
# Image 34 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 35...
# Page chargée avec succès au n° d'index 35 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Musée d'art moderne. Alfred Janniot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 35
# Image cliquée au n° d'index 35
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 35
# Bouton téléchargement trouvé et cliqué au n° d'index 35
# Checkbox des conditions trouvée et cochée au n° d'index 35
# Bouton de téléchargement final trouvé et cliqué au n° d'index 35
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674562_08996D311E3D24F0FCBEF608DCAFEEC4.zip
# Image 35 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 36...
# Page chargée avec succès au n° d'index 36 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Musée d'art moderne. Alfred Janniot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 36
# Image cliquée au n° d'index 36
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 36
# Bouton téléchargement trouvé et cliqué au n° d'index 36
# Checkbox des conditions trouvée et cochée au n° d'index 36
# Bouton de téléchargement final trouvé et cliqué au n° d'index 36
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674556_ABC63F2B91EF170881E5D98D9E69AF30.zip
# Image 36 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 37...
# Page chargée avec succès au n° d'index 37 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Musée d'art moderne. Alfred Janniot. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 37
# Image cliquée au n° d'index 37
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 37
# Bouton téléchargement trouvé et cliqué au n° d'index 37
# Checkbox des conditions trouvée et cochée au n° d'index 37
# Bouton de téléchargement final trouvé et cliqué au n° d'index 37
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674396_F7CAD7574629E1DC6D0D1242F4670643.zip
# Image 37 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 38...
# Page chargée avec succès au n° d'index 38 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de l'URSS. Boris Iofan. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 38
# Image cliquée au n° d'index 38
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 38
# Bouton téléchargement trouvé et cliqué au n° d'index 38
# Checkbox des conditions trouvée et cochée au n° d'index 38
# Bouton de téléchargement final trouvé et cliqué au n° d'index 38
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674600_B52F33A2FA51369FCEB747AB9677EFBB.zip
# Image 38 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 39...
# Page chargée avec succès au n° d'index 39 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de l'URSS. Boris Iofan. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 39
# Image cliquée au n° d'index 39
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 39
# Bouton téléchargement trouvé et cliqué au n° d'index 39
# Checkbox des conditions trouvée et cochée au n° d'index 39
# Bouton de téléchargement final trouvé et cliqué au n° d'index 39
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674610_1FE60E7206E9DF753BCD6A53328371C7.zip
# Image 39 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 40...
# Page chargée avec succès au n° d'index 40 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de l'URSS. Boris Iofan. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 40
# Image cliquée au n° d'index 40
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 40
# Bouton téléchargement trouvé et cliqué au n° d'index 40
# Checkbox des conditions trouvée et cochée au n° d'index 40
# Bouton de téléchargement final trouvé et cliqué au n° d'index 40
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674605_9564D74C1C23CD0CDD446D10E20CBA0C.zip
# Image 40 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 41...
# Page chargée avec succès au n° d'index 41 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de l'URSS. Boris Iofan. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 41
# Image cliquée au n° d'index 41
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 41
# Bouton téléchargement trouvé et cliqué au n° d'index 41
# Checkbox des conditions trouvée et cochée au n° d'index 41
# Bouton de téléchargement final trouvé et cliqué au n° d'index 41
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674609_3CF97A10F141281A28390BD77F9998B9.zip
# Image 41 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 42...
# Page chargée avec succès au n° d'index 42 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de la Grande Bretagne. Oliver Hill et le major Pick, architectes du pavillon. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 42
# Image cliquée au n° d'index 42
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 42
# Bouton téléchargement trouvé et cliqué au n° d'index 42
# Checkbox des conditions trouvée et cochée au n° d'index 42
# Bouton de téléchargement final trouvé et cliqué au n° d'index 42
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001675023_D6CC0BD5A8E7A136310D8A174DBF3971.zip
# Image 42 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 43...
# Page chargée avec succès au n° d'index 43 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon de la Grande Bretagne. Oliver Hill et le major Pick, architectes du pavillon. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 43
# Image cliquée au n° d'index 43
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 43
# Bouton téléchargement trouvé et cliqué au n° d'index 43
# Checkbox des conditions trouvée et cochée au n° d'index 43
# Bouton de téléchargement final trouvé et cliqué au n° d'index 43
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001675024_5CF6D23886B49FCE020CD8EC2861EA25.zip
# Image 43 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 44...
# Page chargée avec succès au n° d'index 44 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon suédois. Sven Ivar Lind. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 44
# Image cliquée au n° d'index 44
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 44
# Bouton téléchargement trouvé et cliqué au n° d'index 44
# Checkbox des conditions trouvée et cochée au n° d'index 44
# Bouton de téléchargement final trouvé et cliqué au n° d'index 44
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001675022_BE007787F4375E7A6FA829E5E705D211.zip
# Image 44 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 45...
# Page chargée avec succès au n° d'index 45 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs. Pavillon suédois. Sven Ivar Lind. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 45
# Image cliquée au n° d'index 45
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 45
# Bouton téléchargement trouvé et cliqué au n° d'index 45
# Checkbox des conditions trouvée et cochée au n° d'index 45
# Bouton de téléchargement final trouvé et cliqué au n° d'index 45
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001675021_289934A89075AE8FABBF596D92145A07.zip
# Image 45 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 46...
# Page chargée avec succès au n° d'index 46 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 46
# Image cliquée au n° d'index 46
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 46
# Bouton téléchargement trouvé et cliqué au n° d'index 46
# Checkbox des conditions trouvée et cochée au n° d'index 46
# Bouton de téléchargement final trouvé et cliqué au n° d'index 46
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674105_D149C6CFDBAD73457DC2F8DC972625BE.zip
# Image 46 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 47...
# Page chargée avec succès au n° d'index 47 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 47
# Image cliquée au n° d'index 47
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 47
# Bouton téléchargement trouvé et cliqué au n° d'index 47
# Checkbox des conditions trouvée et cochée au n° d'index 47
# Bouton de téléchargement final trouvé et cliqué au n° d'index 47
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674300_7C09E362756415E748AA91F7DE261BF9.zip
# Image 47 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 48...
# Page chargée avec succès au n° d'index 48 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 48
# Image cliquée au n° d'index 48
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 48
# Bouton téléchargement trouvé et cliqué au n° d'index 48
# Checkbox des conditions trouvée et cochée au n° d'index 48
# Bouton de téléchargement final trouvé et cliqué au n° d'index 48
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674302_3DC37E0D1DD65BCB939A4EC433BA5341.zip
# Image 48 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 49...
# Page chargée avec succès au n° d'index 49 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 49
# Image cliquée au n° d'index 49
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 49
# Bouton téléchargement trouvé et cliqué au n° d'index 49
# Checkbox des conditions trouvée et cochée au n° d'index 49
# Bouton de téléchargement final trouvé et cliqué au n° d'index 49
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674310_F4442EB611579542CA38240FFFFC6CDE.zip
# Image 49 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 50...
# Page chargée avec succès au n° d'index 50 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 50
# Image cliquée au n° d'index 50
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 50
# Bouton téléchargement trouvé et cliqué au n° d'index 50
# Checkbox des conditions trouvée et cochée au n° d'index 50
# Bouton de téléchargement final trouvé et cliqué au n° d'index 50
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673712_7CDD17F64C7B134667204A83B364B604.zip
# Image 50 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 51...
# Page chargée avec succès au n° d'index 51 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 51
# Image cliquée au n° d'index 51
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 51
# Bouton téléchargement trouvé et cliqué au n° d'index 51
# Checkbox des conditions trouvée et cochée au n° d'index 51
# Bouton de téléchargement final trouvé et cliqué au n° d'index 51
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674306_EAA6EFAB77AC209E3EEB46C091E8B613.zip
# Image 51 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 52...
# Page chargée avec succès au n° d'index 52 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 52
# Image cliquée au n° d'index 52
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 52
# Bouton téléchargement trouvé et cliqué au n° d'index 52
# Checkbox des conditions trouvée et cochée au n° d'index 52
# Bouton de téléchargement final trouvé et cliqué au n° d'index 52
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674313_91C2EBED766B72E45CBE4310D801FE04.zip
# Image 52 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 53...
# Page chargée avec succès au n° d'index 53 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Plusieurs images détectées, première image cliquée au n° d'index 53
# Basculé sur la nouvelle fenêtre et fermé l'onglet original pour l'image au n° d'index 53
# Image trouvée par XPATH alternatif (classique) n° d'index 53
# Image cliquée au n° d'index 53
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 53
# Bouton téléchargement trouvé et cliqué au n° d'index 53
# Checkbox des conditions trouvée et cochée au n° d'index 53
# Bouton de téléchargement final trouvé et cliqué au n° d'index 53
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/h__ark__73873_pf0001615222_0001_5793C00972158AA0B72EC08E9D4F0E2F.zip
# Image 53 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 54...
# Page chargée avec succès au n° d'index 54 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 54
# Image cliquée au n° d'index 54
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 54
# Bouton téléchargement trouvé et cliqué au n° d'index 54
# Checkbox des conditions trouvée et cochée au n° d'index 54
# Bouton de téléchargement final trouvé et cliqué au n° d'index 54
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673799_19EDD6C1F1F38DB0970514EE03F94019.zip
# Image 54 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 55...
# Page chargée avec succès au n° d'index 55 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 55
# Image cliquée au n° d'index 55
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 55
# Bouton téléchargement trouvé et cliqué au n° d'index 55
# Checkbox des conditions trouvée et cochée au n° d'index 55
# Bouton de téléchargement final trouvé et cliqué au n° d'index 55
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673722_9349A9EABD427651970AD27F7CF56331.zip
# Image 55 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 56...
# Page chargée avec succès au n° d'index 56 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 56
# Image cliquée au n° d'index 56
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 56
# Bouton téléchargement trouvé et cliqué au n° d'index 56
# Checkbox des conditions trouvée et cochée au n° d'index 56
# Bouton de téléchargement final trouvé et cliqué au n° d'index 56
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673228_36B83402BA5B52192344CAD371A53127.zip
# Image 56 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 57...
# Page chargée avec succès au n° d'index 57 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 57
# Image cliquée au n° d'index 57
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 57
# Bouton téléchargement trouvé et cliqué au n° d'index 57
# Checkbox des conditions trouvée et cochée au n° d'index 57
# Bouton de téléchargement final trouvé et cliqué au n° d'index 57
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674308_5CD65C5B0CD5305119ED42270DA80CA0.zip
# Image 57 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 58...
# Page chargée avec succès au n° d'index 58 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 58
# Image cliquée au n° d'index 58
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 58
# Bouton téléchargement trouvé et cliqué au n° d'index 58
# Checkbox des conditions trouvée et cochée au n° d'index 58
# Bouton de téléchargement final trouvé et cliqué au n° d'index 58
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674085_941234D5991D70D651A86E4409139FA0.zip
# Image 58 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 59...
# Page chargée avec succès au n° d'index 59 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 59
# Image cliquée au n° d'index 59
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 59
# Bouton téléchargement trouvé et cliqué au n° d'index 59
# Checkbox des conditions trouvée et cochée au n° d'index 59
# Bouton de téléchargement final trouvé et cliqué au n° d'index 59
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673246_D893E4C1EF19BAA2CCB7AD9628E47A1A.zip
# Image 59 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 60...
# Page chargée avec succès au n° d'index 60 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 60
# Image cliquée au n° d'index 60
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 60
# Bouton téléchargement trouvé et cliqué au n° d'index 60
# Checkbox des conditions trouvée et cochée au n° d'index 60
# Bouton de téléchargement final trouvé et cliqué au n° d'index 60
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673734_E0B52E0B5B3947D7F36FFCDFE9FC4D70.zip
# Image 60 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 61...
# Page chargée avec succès au n° d'index 61 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 61
# Image cliquée au n° d'index 61
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 61
# Bouton téléchargement trouvé et cliqué au n° d'index 61
# Checkbox des conditions trouvée et cochée au n° d'index 61
# Bouton de téléchargement final trouvé et cliqué au n° d'index 61
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001674086_4FE3AB73AF01B7768A574B64EE71D8AB.zip
# Image 61 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 62...
# Page chargée avec succès au n° d'index 62 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 62
# Image cliquée au n° d'index 62
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 62
# Bouton téléchargement trouvé et cliqué au n° d'index 62
# Checkbox des conditions trouvée et cochée au n° d'index 62
# Bouton de téléchargement final trouvé et cliqué au n° d'index 62
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673737_D35FA1BA45BBC45CE812BE2C6751124A.zip
# Image 62 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 63...
# Page chargée avec succès au n° d'index 63 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 63
# Image cliquée au n° d'index 63
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 63
# Bouton téléchargement trouvé et cliqué au n° d'index 63
# Checkbox des conditions trouvée et cochée au n° d'index 63
# Bouton de téléchargement final trouvé et cliqué au n° d'index 63
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673745_DB2E870D8C830026D1F9F5F42B4EDBD4.zip
# Image 63 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 64...
# Page chargée avec succès au n° d'index 64 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 64
# Image cliquée au n° d'index 64
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 64
# Bouton téléchargement trouvé et cliqué au n° d'index 64
# Checkbox des conditions trouvée et cochée au n° d'index 64
# Bouton de téléchargement final trouvé et cliqué au n° d'index 64
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673736_CCE2B629408E900BB660EE5A2B4328D6.zip
# Image 64 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 65...
# Page chargée avec succès au n° d'index 65 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 65
# Image cliquée au n° d'index 65
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 65
# Bouton téléchargement trouvé et cliqué au n° d'index 65
# Checkbox des conditions trouvée et cochée au n° d'index 65
# Bouton de téléchargement final trouvé et cliqué au n° d'index 65
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001673797_E22EB4B53C37AA2EAF56A0533F28A319.zip
# Image 65 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 66...
# Page chargée avec succès au n° d'index 66 (titre: [Exposition internationale des Arts et Techniques dans la Vie moderne. 1937. Préparatifs] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# ...
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 156
# Image cliquée au n° d'index 156
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 156
# Bouton téléchargement trouvé et cliqué au n° d'index 156
# Checkbox des conditions trouvée et cochée au n° d'index 156
# Bouton de téléchargement final trouvé et cliqué au n° d'index 156
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615327_978848D843F97710204274FF64D91D70.zip
# Image 156 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 157...
# Page chargée avec succès au n° d'index 157 (titre: [Exposition internationale des Arts et techniques de 1937. Palais des tissus, des Gobelins et de l'UCAF. Tissu d'inspiration chinoise. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 157
# Image cliquée au n° d'index 157
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 157
# Bouton téléchargement trouvé et cliqué au n° d'index 157
# Checkbox des conditions trouvée et cochée au n° d'index 157
# Bouton de téléchargement final trouvé et cliqué au n° d'index 157
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615298_3112D8016CF95AAB5F2750F22A915F08.zip
# Image 157 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 158...
# Page chargée avec succès au n° d'index 158 (titre: [Exposition internationale des Arts et Techniques de 1937. Panneau décoratif en faïence stannifère d'après la composition de Zadkine "Le Tourneur". Pavillon de la céramique. Galerie de Sèvres. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 158
# Image cliquée au n° d'index 158
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 158
# Bouton téléchargement trouvé et cliqué au n° d'index 158
# Checkbox des conditions trouvée et cochée au n° d'index 158
# Bouton de téléchargement final trouvé et cliqué au n° d'index 158
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001614761_38460E8050D9AA8DD15F4C86AF8E7D8B.zip
# Image 158 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 159...
# Page chargée avec succès au n° d'index 159 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Avion Caudron Renault suspendu. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 159
# Image cliquée au n° d'index 159
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 159
# Bouton téléchargement trouvé et cliqué au n° d'index 159
# Checkbox des conditions trouvée et cochée au n° d'index 159
# Bouton de téléchargement final trouvé et cliqué au n° d'index 159
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615620_0E6AA01B57E305D06D98E6D07B55E88A.zip
# Image 159 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 160...
# Page chargée avec succès au n° d'index 160 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Avion suspendu Caudron Renault. Décor dans le hall tronconique par l'association Art et Lumière de F. Aublet et R. Delaunay. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 160
# Image cliquée au n° d'index 160
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 160
# Bouton téléchargement trouvé et cliqué au n° d'index 160
# Checkbox des conditions trouvée et cochée au n° d'index 160
# Bouton de téléchargement final trouvé et cliqué au n° d'index 160
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615617_20FF7520181B3B5A294885DB29E42622.zip
# Image 160 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 161...
# Page chargée avec succès au n° d'index 161 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique : décor peint par Albert Gleizes et Robert Delaunay. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 161
# Image cliquée au n° d'index 161
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 161
# Bouton téléchargement trouvé et cliqué au n° d'index 161
# Checkbox des conditions trouvée et cochée au n° d'index 161
# Bouton de téléchargement final trouvé et cliqué au n° d'index 161
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615612_B756A1A088F58F5AEBF4ACEDF98D20F9.zip
# Image 161 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 162...
# Page chargée avec succès au n° d'index 162 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique décoré par l'association Art et Lumière de F. Aublet et R. Delaunay. Avion Caudron Renault suspendu. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 162
# Image cliquée au n° d'index 162
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 162
# Bouton téléchargement trouvé et cliqué au n° d'index 162
# Checkbox des conditions trouvée et cochée au n° d'index 162
# Bouton de téléchargement final trouvé et cliqué au n° d'index 162
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616018_69632264EBFE9D8E1EEBE27C3B206942.zip
# Image 162 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 163...
# Page chargée avec succès au n° d'index 163 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique décoré par l'association Art et Lumière de F. Aublet et R. Delaunay. Avions suspendus. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 163
# Image cliquée au n° d'index 163
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 163
# Bouton téléchargement trouvé et cliqué au n° d'index 163
# Checkbox des conditions trouvée et cochée au n° d'index 163
# Bouton de téléchargement final trouvé et cliqué au n° d'index 163
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616025_CFC8EFEF8ACA52DA56AAC5E750F02CD9.zip
# Image 163 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 164...
# Page chargée avec succès au n° d'index 164 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique. Avion Caudron Renault suspendu. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 164
# Image cliquée au n° d'index 164
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 164
# Bouton téléchargement trouvé et cliqué au n° d'index 164
# Checkbox des conditions trouvée et cochée au n° d'index 164
# Bouton de téléchargement final trouvé et cliqué au n° d'index 164
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615622_EAABC236D2BC7650877FB46B08D92F10.zip
# Image 164 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 165...
# Page chargée avec succès au n° d'index 165 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique. Départ de la passerelle conduisant à l'avion suspendu. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 165
# Image cliquée au n° d'index 165
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 165
# Bouton téléchargement trouvé et cliqué au n° d'index 165
# Checkbox des conditions trouvée et cochée au n° d'index 165
# Bouton de téléchargement final trouvé et cliqué au n° d'index 165
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616020_86745E09005A6A27DE595238C5829FAA.zip
# Image 165 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 166...
# Page chargée avec succès au n° d'index 166 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Hall tronconique. Gros plan sur la passerelle conduisant au Caudron Renault. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 166
# Image cliquée au n° d'index 166
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 166
# Bouton téléchargement trouvé et cliqué au n° d'index 166
# Checkbox des conditions trouvée et cochée au n° d'index 166
# Bouton de téléchargement final trouvé et cliqué au n° d'index 166
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616022_3CF2E28FE7FE28CA356BD06B71F1DECB.zip
# Image 166 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 167...
# Page chargée avec succès au n° d'index 167 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Aéronautique. Vue intérieure du hall tronconique : décor de l'association Art et lumière peint par F. Aublet et Robert Delaunay. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 167
# Image cliquée au n° d'index 167
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 167
# Bouton téléchargement trouvé et cliqué au n° d'index 167
# Checkbox des conditions trouvée et cochée au n° d'index 167
# Bouton de téléchargement final trouvé et cliqué au n° d'index 167
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001615615_E253545CB9F58963D121877E87EBA68E.zip
# Image 167 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 168...
# Page chargée avec succès au n° d'index 168 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Agriculture. Panneaux extérieurs de présentation. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 168
# Image cliquée au n° d'index 168
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 168
# Bouton téléchargement trouvé et cliqué au n° d'index 168
# Checkbox des conditions trouvée et cochée au n° d'index 168
# Bouton de téléchargement final trouvé et cliqué au n° d'index 168
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616030_857E4C5DC6E2A1111543AA5D67004DC1.zip
# Image 168 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 169...
# Page chargée avec succès au n° d'index 169 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Allemagne par l'architecte Albert Speer, vue d'un bateau sur la Seine. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 169
# Image cliquée au n° d'index 169
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 169
# Bouton téléchargement trouvé et cliqué au n° d'index 169
# Checkbox des conditions trouvée et cochée au n° d'index 169
# Bouton de téléchargement final trouvé et cliqué au n° d'index 169
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616032_D0C717503827FE192A866134707BEE2B.zip
# Image 169 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 170...
# Page chargée avec succès au n° d'index 170 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Allemagne par l'architecte Albert Speer. Façade principale surmontée de l'aigle de bronze. Au 1er plan, l'Arabe par Feuchère. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 170
# Image cliquée au n° d'index 170
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 170
# Bouton téléchargement trouvé et cliqué au n° d'index 170
# Checkbox des conditions trouvée et cochée au n° d'index 170
# Bouton de téléchargement final trouvé et cliqué au n° d'index 170
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616034_BC0821A33E0B56543935A91C3CACB0D8.zip
# Image 170 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 171...
# Page chargée avec succès au n° d'index 171 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Allemagne surmonté de l'Aigle, par l'architecte Albert Speer. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 171
# Image cliquée au n° d'index 171
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 171
# Bouton téléchargement trouvé et cliqué au n° d'index 171
# Checkbox des conditions trouvée et cochée au n° d'index 171
# Bouton de téléchargement final trouvé et cliqué au n° d'index 171
# Fichier ZIP trouvé: /home/mathieu/Téléchargements/p__usmarcdef_0001616039_F3EF3D752F26ECE51EA2B703185DD513.zip
# Image 171 extraite et déplacée avec succès ✅
# ZIP supprimé avec succès
# Chargement de la page 172...
# Page chargée avec succès au n° d'index 172 (titre: [Exposition internationale des Arts et techniques de 1937. Pavillon de l'Allemagne surmonté de l'Aigle, par l'architecte Albert Speer. ] : [photographie] - Bibliothèques spécialisées et patrimoniales de la Ville de Paris)
# Pas de gestion multi-image pour cette URL
# Image trouvée par XPATH principal (classique) n° d'index 172
# Image cliquée au n° d'index 172
# Basculé sur la nouvelle fenêtre pour l'image au n° d'index 172
# Bouton téléchargement trouvé et cliqué au n° d'index 172
# Checkbox des conditions trouvée et cochée au n° d'index 172
# Bouton de téléchargement final trouvé et cliqué au n° d'index 172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Lancer le scrapping pour la première fois
# ----> 2 download_image(input_csv)
#
# Cell In[14], line 38, in download_image(input_csv, start_index)
#      36         df.to_csv(input_csv, index=False, encoding="utf-8") # On sauvegarde les modifications.
#      37 elif url.startswith('https://bibliotheques'): # Autrement on détecte que l'image provient du site des bibliothèques spécialisées de Paris.
# ---> 38     success = download_bib(url, index, output_folder, output_path) # On appelle la fonction idoine.
#      39     if success:
#      40         df.at[index, "FICHIER"] = output_path # Pareil on ajoute le filepath à la colonne "FICHIER"
#
# Cell In[20], line 171, in download_bib(url, index, output_folder, output_path)
#     168 # 8. Attendre le téléchargement et traiter le ZIP
#     169 try:
#     170     # Attendre pour le téléchargement
# --> 171     time.sleep(15)
#     173     # Vérifier que le dossier Téléchargements existe
#     174     downloads_dir = os.path.expanduser("~/Téléchargements")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Relancer le scrapping en cas d'interruption 🔂

# %% [markdown]
# 🩹
# **Décommentez ci-dessous et exécutez la cellule pour reprendre un scrapping interrompu**

# %%
# # Reprendre un scrapping interrompu
# output_folder = os.path.join(os.path.dirname(input_csv), 'sortie') # On met le chemin de sortie, c'est-à-dire dans le même dossier que le csv.
# last_index = resume_scrapping(output_folder) # Via la fonction resume_scrapping, on récupère le plus haut index trouvé dans le dossier.
# download_image(input_csv, start_index=last_index+1) # On reprend le téléchargement en attribuant la valeur last_index à la variable start_index, de notre fonction principale de téléchargement, qui est originellement 0 par défaut.
